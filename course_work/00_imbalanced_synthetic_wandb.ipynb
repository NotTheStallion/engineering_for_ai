# %% [markdown]
# This code builds a synthetic imbalanced dataset and runs several classifiers to test different metrics and data augmentation strategies.
# We compute metrics on training set and on hold-out set.
# There is no hyperparameter optimisation.

# %%
# all the imports

import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification

from sklearn.decomposition import PCA

from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import fbeta_score
from sklearn.metrics import balanced_accuracy_score

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.ensemble import BalancedRandomForestClassifier

rng = np.random.RandomState(0)

# %%
# synthetic data in 20D or 2D with 10k samples and 5% imbalance


def generate_data_20d():
    X, y = make_classification(
        n_samples=10000,
        n_features=20,
        n_informative=16,
        n_redundant=2,
        n_repeated=2,
        n_classes=2,
        weights=[0.95, 0.05],
        random_state=rng,
    )
    return X, y


def generate_data_2d():
    X, y = make_classification(
        n_samples=10000,
        n_features=2,
        n_informative=2,
        n_redundant=0,
        n_repeated=0,
        n_classes=2,
        weights=[0.95, 0.05],
        random_state=rng,
    )
    return X, y


# X, y = generate_data_2d()
X, y = generate_data_20d()

# %%
# plot the data
if X.shape[1] != 2:
    # if more than 2 dimensions
    # make a PCA and plot 2 top components
    pca = PCA(n_components=2)
    components = pca.fit_transform(X)

    total_var = pca.explained_variance_ratio_.sum() * 100
    print(f"PCA: Top 2 components explain {total_var:.0f}% of variance")

    plt.scatter(components[:, 0], components[:, 1], c=y)
else:
    # otherwise simply plot 2d data as scatter plot
    plt.scatter(X[:, 0], X[:, 1], c=y)
# Out:
# PCA: Top 2 components explain 54% of variance

# %%
# metrics routine


def metrics(X, y, clf):
    y_hat = clf.predict(X)
    ret_metrics = []
    ret_metrics.append(accuracy_score(y, y_hat))
    ret_metrics.append(precision_score(y, y_hat, zero_division=0))
    ret_metrics.append(recall_score(y, y_hat))
    ret_metrics.append(f1_score(y, y_hat))
    ret_metrics.append(fbeta_score(y, y_hat, beta=0.5))
    ret_metrics.append(balanced_accuracy_score(y, y_hat))
    return ret_metrics


# training routine
def train_standard(X, y, clf):

    model = clf

    # we store metrics there before averaging at the end
    accuracy_list = []
    precision_list = []
    recall_list = []
    f1score_list = []
    fbetascore_list = []
    balanced_accuracy_list = []

    # Defines Stratified K-fold in order to keep
    # the class balance for each fold
    st_k_fold = StratifiedKFold(n_splits=4)

    # get metrics for each fold
    for train_idx, test_idx in st_k_fold.split(X, y):

        # Training fold
        x_train_fold = X[train_idx]
        y_train_fold = y[train_idx]

        # Testing fold
        x_test_fold = X[test_idx]
        y_test_fold = y[test_idx]

        # Train
        model.fit(x_train_fold, y_train_fold)

        # Get metrics
        fold_metrics = metrics(x_test_fold, y_test_fold, model)

        # Save metrics
        accuracy_list.append(fold_metrics[0])
        precision_list.append(fold_metrics[1])
        recall_list.append(fold_metrics[2])
        f1score_list.append(fold_metrics[3])
        fbetascore_list.append(fold_metrics[4])
        balanced_accuracy_list.append(fold_metrics[5])

    # compute average metrics
    metrics_train = []
    metrics_train.append(np.mean(accuracy_list))
    metrics_train.append(np.mean(precision_list))
    metrics_train.append(np.mean(recall_list))
    metrics_train.append(np.mean(f1score_list))
    metrics_train.append(np.mean(fbetascore_list))
    metrics_train.append(np.mean(balanced_accuracy_list))

    # retrain on the whole train dataset
    model.fit(X, y)
    return (model, metrics_train)

# %%
# try different data augmentation strategies.
# returns size of dataset, trained model, and metrics.

# trains the classifier without touching the data.
def no_resampling(x, y, clf):
    return (x.shape[0], train_standard(x, y, clf))


# Applies Random Undersampling then trains the classifier
def under_sampler(x, y, clf):
    rus = RandomUnderSampler(random_state=rng)
    rx, ry = rus.fit_resample(x, y)
    return (rx.shape[0], train_standard(rx, ry, clf))


# Applies Random Oversampling then trains the classifier
def over_sampler(x, y, clf):
    ros = RandomOverSampler(random_state=rng)
    rx, ry = ros.fit_resample(x, y)
    return (rx.shape[0], train_standard(rx, ry, clf))


# Applies Synthetic Data Augmentation through SMOTE then trains the classifier
def smote(x, y, clf):
    smote = SMOTE(random_state=rng)
    rx, ry = smote.fit_resample(x, y)
    return (rx.shape[0], train_standard(rx, ry, clf))

# %%
# experiment!

# we have X and y, let's build the hold out
X_train, X_hold, y_train, y_hold = train_test_split(
    X, y, test_size=0.10, random_state=rng, stratify=y
)
size_hold_out = X_hold.shape[0]

# these are all the classifiers we want to test
clfs = []
clfs.append(DecisionTreeClassifier(max_depth=3, random_state=rng))
clfs.append(
    DecisionTreeClassifier(max_depth=3, class_weight="balanced", random_state=rng)
)
clfs.append(RandomForestClassifier(max_depth=3, random_state=rng))
clfs.append(
    RandomForestClassifier(max_depth=3, class_weight="balanced", random_state=rng)
)
clfs.append(make_pipeline(StandardScaler(), SVC(gamma="auto", random_state=rng)))
clfs.append(
    make_pipeline(
        StandardScaler(), SVC(gamma="auto", class_weight="balanced", random_state=rng)
    )
)
clfs.append(BalancedRandomForestClassifier(n_estimators=100, random_state=rng))

# loop on classifiers, train them, get metrics on train set and hold out, and print all this out.

# for clf in clfs:
#     print(
#         f"Model            t_acc t_pre t_rec t_f1  t_fb  t_bac t_size\
#     h_acc h_pre h_rec h_f1  h_fb  h_bac h_size"
#     )
#     #
#     (size_train, (best_clf, metrics_train)) = no_resampling(X_train, y_train, clf)
#     metrics_hold_out = metrics(X_hold, y_hold, best_clf)
#     print(
#         f"{str(clf)[0:10]} n/a   {metrics_train[0]:.3f} {metrics_train[1]:.3f} {metrics_train[2]:.3f} {metrics_train[3]:.3f} {metrics_train[4]:.3f} {metrics_train[5]:.3f} {size_train:>5d} \
#     {metrics_hold_out[0]:.3f} {metrics_hold_out[1]:.3f} {metrics_hold_out[2]:.3f} {metrics_hold_out[3]:.3f} {metrics_hold_out[4]:.3f} {metrics_hold_out[5]:.3f} {size_hold_out:>5d}"
#     )
#     #
#     (size_train, (best_clf, metrics_train)) = under_sampler(X_train, y_train, clf)
#     metrics_hold_out = metrics(X_hold, y_hold, best_clf)
#     print(
#         f"{str(clf)[0:10]} under {metrics_train[0]:.3f} {metrics_train[1]:.3f} {metrics_train[2]:.3f} {metrics_train[3]:.3f} {metrics_train[4]:.3f} {metrics_train[5]:.3f} {size_train:>5d} \
#     {metrics_hold_out[0]:.3f} {metrics_hold_out[1]:.3f} {metrics_hold_out[2]:.3f} {metrics_hold_out[3]:.3f} {metrics_hold_out[4]:.3f} {metrics_hold_out[5]:.3f} {size_hold_out:>5d}"
#     )
#     #
#     (size_train, (best_clf, metrics_train)) = over_sampler(X_train, y_train, clf)
#     metrics_hold_out = metrics(X_hold, y_hold, best_clf)
#     print(
#         f"{str(clf)[0:10]} over  {metrics_train[0]:.3f} {metrics_train[1]:.3f} {metrics_train[2]:.3f} {metrics_train[3]:.3f} {metrics_train[4]:.3f} {metrics_train[5]:.3f} {size_train:>5d} \
#     {metrics_hold_out[0]:.3f} {metrics_hold_out[1]:.3f} {metrics_hold_out[2]:.3f} {metrics_hold_out[3]:.3f} {metrics_hold_out[4]:.3f} {metrics_hold_out[5]:.3f} {size_hold_out:>5d}"
#     )
#     #
#     (size_train, (best_clf, metrics_train)) = smote(X_train, y_train, clf)
#     metrics_hold_out = metrics(X_hold, y_hold, best_clf)
#     print(
#         f"{str(clf)[0:10]} smote {metrics_train[0]:.3f} {metrics_train[1]:.3f} {metrics_train[2]:.3f} {metrics_train[3]:.3f} {metrics_train[4]:.3f} {metrics_train[5]:.3f} {size_train:>5d} \
#     {metrics_hold_out[0]:.3f} {metrics_hold_out[1]:.3f} {metrics_hold_out[2]:.3f} {metrics_hold_out[3]:.3f} {metrics_hold_out[4]:.3f} {metrics_hold_out[5]:.3f} {size_hold_out:>5d}"
#     )

# %%
import wandb
from sklearn.metrics import accuracy_score, f1_score

wandb.init(project="imbalanced_dataset_model_comparison")

clfs = []
clfs.append(DecisionTreeClassifier(max_depth=3, random_state=rng))
clfs.append(
    DecisionTreeClassifier(max_depth=3, class_weight="balanced", random_state=rng)
)
clfs.append(RandomForestClassifier(max_depth=3, random_state=rng))
clfs.append(
    RandomForestClassifier(max_depth=3, class_weight="balanced", random_state=rng)
)
clfs.append(make_pipeline(StandardScaler(), SVC(gamma="auto", random_state=rng)))
clfs.append(
    make_pipeline(
        StandardScaler(), SVC(gamma="auto", class_weight="balanced", random_state=rng)
    )
)
clfs.append(BalancedRandomForestClassifier(n_estimators=100, random_state=rng))
models = {'DesTree': clfs[0], 'BDesTree': clfs[1], 'RandForest': clfs[2], 'BRandForest': clfs[3], 'SVC': clfs[4], 'BSVC': clfs[5], 'BalRandForest': clfs[6]}

samplers = {'no_resampling': no_resampling, 'under_sampler': under_sampler, 'over_sampler':over_sampler, 'smote':smote}

for sampling_method in samplers.keys():
    for model_name, model in models.items():
        wandb_run = wandb.init(project="imbalanced_dataset_model_comparison", name=model_name+"_"+sampling_method)
        
        # get sampling methode
        sampler = samplers[sampling_method]
        (size_train, (best_clf, metrics_train)) = sampler(X_train, y_train, model)
        metrics_hold_out = metrics(X_hold, y_hold, best_clf)
        
        wandb.log({
            "model_name": model_name,
            "sampling_method": sampling_method,
            "accuracy": metrics_train[0],
            "precision": metrics_train[1],
            "recall" :  metrics_train[2],
            "f1_score": metrics_train[3],
            "fbeta_score" : metrics_train[4],
            "balanced_accuracy" : metrics_train[5],
            "train_size": size_train,
            "ho_accuracy": metrics_hold_out[0],
            "ho_precision": metrics_hold_out[1],
            "ho_recall" :  metrics_hold_out[2],
            "ho_f1_score": metrics_hold_out[3],
            "ho_fbeta_score" : metrics_hold_out[4],
            "ho_balanced_accuracy" : metrics_hold_out[5],
            "ho_size": size_hold_out
        })
        
        wandb_run.finish()

wandb.finish()
# Out:
# wandb: Currently logged in as: notthestallion (the_ranch) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022407-kn42xtb6</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/kn42xtb6' target="_blank">swept-smoke-47</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/kn42xtb6' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/kn42xtb6</a>
# Finishing previous runs because reinit is set to 'default'.
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
#  View run <strong style="color:#cdcd00">swept-smoke-47</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/kn42xtb6' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/kn42xtb6</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022407-kn42xtb6/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022408-qcc0hqgo</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/qcc0hqgo' target="_blank">DesTree_no_resampling</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/qcc0hqgo' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/qcc0hqgo</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94711</td></tr><tr><td>balanced_accuracy</td><td>0.54199</td></tr><tr><td>f1_score</td><td>0.15126</td></tr><tr><td>fbeta_score</td><td>0.27575</td></tr><tr><td>ho_accuracy</td><td>0.951</td></tr><tr><td>ho_balanced_accuracy</td><td>0.56311</td></tr><tr><td>ho_f1_score</td><td>0.22222</td></tr><tr><td>ho_fbeta_score</td><td>0.4023</td></tr><tr><td>ho_precision</td><td>0.875</td></tr><tr><td>ho_recall</td><td>0.12727</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DesTree_no_resampling</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/qcc0hqgo' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/qcc0hqgo</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022408-qcc0hqgo/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022411-cmxxh461</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/cmxxh461' target="_blank">BDesTree_no_resampling</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/cmxxh461' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/cmxxh461</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.75067</td></tr><tr><td>balanced_accuracy</td><td>0.66777</td></tr><tr><td>f1_score</td><td>0.21043</td></tr><tr><td>fbeta_score</td><td>0.15475</td></tr><tr><td>ho_accuracy</td><td>0.781</td></tr><tr><td>ho_balanced_accuracy</td><td>0.67864</td></tr><tr><td>ho_f1_score</td><td>0.22064</td></tr><tr><td>ho_fbeta_score</td><td>0.16163</td></tr><tr><td>ho_precision</td><td>0.13717</td></tr><tr><td>ho_recall</td><td>0.56364</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BDesTree_no_resampling</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/cmxxh461' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/cmxxh461</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022411-cmxxh461/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022412-42fgpaay</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/42fgpaay' target="_blank">RandForest_no_resampling</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/42fgpaay' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/42fgpaay</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94489</td></tr><tr><td>balanced_accuracy</td><td>0.5</td></tr><tr><td>f1_score</td><td>0</td></tr><tr><td>fbeta_score</td><td>0</td></tr><tr><td>ho_accuracy</td><td>0.945</td></tr><tr><td>ho_balanced_accuracy</td><td>0.5</td></tr><tr><td>ho_f1_score</td><td>0</td></tr><tr><td>ho_fbeta_score</td><td>0</td></tr><tr><td>ho_precision</td><td>0</td></tr><tr><td>ho_recall</td><td>0</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RandForest_no_resampling</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/42fgpaay' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/42fgpaay</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022412-42fgpaay/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022417-2qsnu8nu</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/2qsnu8nu' target="_blank">BRandForest_no_resampling</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/2qsnu8nu' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/2qsnu8nu</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.83489</td></tr><tr><td>balanced_accuracy</td><td>0.75125</td></tr><tr><td>f1_score</td><td>0.30539</td></tr><tr><td>fbeta_score</td><td>0.23121</td></tr><tr><td>ho_accuracy</td><td>0.816</td></tr><tr><td>ho_balanced_accuracy</td><td>0.76566</td></tr><tr><td>ho_f1_score</td><td>0.29771</td></tr><tr><td>ho_fbeta_score</td><td>0.22084</td></tr><tr><td>ho_precision</td><td>0.18841</td></tr><tr><td>ho_recall</td><td>0.70909</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BRandForest_no_resampling</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/2qsnu8nu' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/2qsnu8nu</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022417-2qsnu8nu/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022421-iklp7p5w</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/iklp7p5w' target="_blank">SVC_no_resampling</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/iklp7p5w' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/iklp7p5w</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.97944</td></tr><tr><td>balanced_accuracy</td><td>0.81825</td></tr><tr><td>f1_score</td><td>0.77337</td></tr><tr><td>fbeta_score</td><td>0.88761</td></tr><tr><td>ho_accuracy</td><td>0.982</td></tr><tr><td>ho_balanced_accuracy</td><td>0.85349</td></tr><tr><td>ho_f1_score</td><td>0.8125</td></tr><tr><td>ho_fbeta_score</td><td>0.89041</td></tr><tr><td>ho_precision</td><td>0.95122</td></tr><tr><td>ho_recall</td><td>0.70909</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SVC_no_resampling</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/iklp7p5w' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/iklp7p5w</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022421-iklp7p5w/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022424-tos1e05h</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/tos1e05h' target="_blank">BSVC_no_resampling</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/tos1e05h' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/tos1e05h</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.97578</td></tr><tr><td>balanced_accuracy</td><td>0.91789</td></tr><tr><td>f1_score</td><td>0.79527</td></tr><tr><td>fbeta_score</td><td>0.76437</td></tr><tr><td>ho_accuracy</td><td>0.967</td></tr><tr><td>ho_balanced_accuracy</td><td>0.93117</td></tr><tr><td>ho_f1_score</td><td>0.74809</td></tr><tr><td>ho_fbeta_score</td><td>0.68245</td></tr><tr><td>ho_precision</td><td>0.64474</td></tr><tr><td>ho_recall</td><td>0.89091</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BSVC_no_resampling</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/tos1e05h' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/tos1e05h</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022424-tos1e05h/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022427-vgw93ukg</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/vgw93ukg' target="_blank">BalRandForest_no_resampling</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/vgw93ukg' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/vgw93ukg</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94922</td></tr><tr><td>balanced_accuracy</td><td>0.83359</td></tr><tr><td>f1_score</td><td>0.60533</td></tr><tr><td>fbeta_score</td><td>0.55904</td></tr><tr><td>ho_accuracy</td><td>0.943</td></tr><tr><td>ho_balanced_accuracy</td><td>0.8671</td></tr><tr><td>ho_f1_score</td><td>0.6014</td></tr><tr><td>ho_fbeta_score</td><td>0.52826</td></tr><tr><td>ho_precision</td><td>0.48864</td></tr><tr><td>ho_recall</td><td>0.78182</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BalRandForest_no_resampling</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/vgw93ukg' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/vgw93ukg</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022427-vgw93ukg/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022430-o5zabfz1</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/o5zabfz1' target="_blank">DesTree_under_sampler</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/o5zabfz1' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/o5zabfz1</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.6875</td></tr><tr><td>balanced_accuracy</td><td>0.6875</td></tr><tr><td>f1_score</td><td>0.65734</td></tr><tr><td>fbeta_score</td><td>0.69899</td></tr><tr><td>ho_accuracy</td><td>0.757</td></tr><tr><td>ho_balanced_accuracy</td><td>0.68307</td></tr><tr><td>ho_f1_score</td><td>0.21359</td></tr><tr><td>ho_fbeta_score</td><td>0.15406</td></tr><tr><td>ho_precision</td><td>0.12992</td></tr><tr><td>ho_recall</td><td>0.6</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DesTree_under_sampler</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/o5zabfz1' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/o5zabfz1</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022430-o5zabfz1/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022432-fjz5z9w6</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/fjz5z9w6' target="_blank">BDesTree_under_sampler</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/fjz5z9w6' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/fjz5z9w6</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.64113</td></tr><tr><td>balanced_accuracy</td><td>0.64113</td></tr><tr><td>f1_score</td><td>0.5942</td></tr><tr><td>fbeta_score</td><td>0.6453</td></tr><tr><td>ho_accuracy</td><td>0.806</td></tr><tr><td>ho_balanced_accuracy</td><td>0.67475</td></tr><tr><td>ho_f1_score</td><td>0.23016</td></tr><tr><td>ho_fbeta_score</td><td>0.172</td></tr><tr><td>ho_precision</td><td>0.14721</td></tr><tr><td>ho_recall</td><td>0.52727</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BDesTree_under_sampler</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/fjz5z9w6' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/fjz5z9w6</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022432-fjz5z9w6/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022434-gszxazby</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/gszxazby' target="_blank">RandForest_under_sampler</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/gszxazby' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/gszxazby</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.75605</td></tr><tr><td>balanced_accuracy</td><td>0.75605</td></tr><tr><td>f1_score</td><td>0.75198</td></tr><tr><td>fbeta_score</td><td>0.76026</td></tr><tr><td>ho_accuracy</td><td>0.724</td></tr><tr><td>ho_balanced_accuracy</td><td>0.75979</td></tr><tr><td>ho_f1_score</td><td>0.24176</td></tr><tr><td>ho_fbeta_score</td><td>0.17041</td></tr><tr><td>ho_precision</td><td>0.14239</td></tr><tr><td>ho_recall</td><td>0.8</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RandForest_under_sampler</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/gszxazby' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/gszxazby</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022434-gszxazby/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022436-08avvlnq</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/08avvlnq' target="_blank">BRandForest_under_sampler</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/08avvlnq' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/08avvlnq</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.75504</td></tr><tr><td>balanced_accuracy</td><td>0.75504</td></tr><tr><td>f1_score</td><td>0.75584</td></tr><tr><td>fbeta_score</td><td>0.75484</td></tr><tr><td>ho_accuracy</td><td>0.72</td></tr><tr><td>ho_balanced_accuracy</td><td>0.76623</td></tr><tr><td>ho_f1_score</td><td>0.24324</td></tr><tr><td>ho_fbeta_score</td><td>0.1711</td></tr><tr><td>ho_precision</td><td>0.14286</td></tr><tr><td>ho_recall</td><td>0.81818</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BRandForest_under_sampler</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/08avvlnq' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/08avvlnq</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022436-08avvlnq/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022438-1q1vt95z</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/1q1vt95z' target="_blank">SVC_under_sampler</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/1q1vt95z' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/1q1vt95z</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.9002</td></tr><tr><td>balanced_accuracy</td><td>0.9002</td></tr><tr><td>f1_score</td><td>0.89711</td></tr><tr><td>fbeta_score</td><td>0.91506</td></tr><tr><td>ho_accuracy</td><td>0.929</td></tr><tr><td>ho_balanced_accuracy</td><td>0.91962</td></tr><tr><td>ho_f1_score</td><td>0.5848</td></tr><tr><td>ho_fbeta_score</td><td>0.4817</td></tr><tr><td>ho_precision</td><td>0.43103</td></tr><tr><td>ho_recall</td><td>0.90909</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SVC_under_sampler</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/1q1vt95z' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/1q1vt95z</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022438-1q1vt95z/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022439-bqvug7tw</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/bqvug7tw' target="_blank">BSVC_under_sampler</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/bqvug7tw' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/bqvug7tw</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.90323</td></tr><tr><td>balanced_accuracy</td><td>0.90323</td></tr><tr><td>f1_score</td><td>0.89919</td></tr><tr><td>fbeta_score</td><td>0.92254</td></tr><tr><td>ho_accuracy</td><td>0.926</td></tr><tr><td>ho_balanced_accuracy</td><td>0.91804</td></tr><tr><td>ho_f1_score</td><td>0.57471</td></tr><tr><td>ho_fbeta_score</td><td>0.47081</td></tr><tr><td>ho_precision</td><td>0.42017</td></tr><tr><td>ho_recall</td><td>0.90909</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BSVC_under_sampler</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/bqvug7tw' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/bqvug7tw</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022439-bqvug7tw/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022441-bahth1io</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/bahth1io' target="_blank">BalRandForest_under_sampler</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/bahth1io' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/bahth1io</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.82863</td></tr><tr><td>balanced_accuracy</td><td>0.82863</td></tr><tr><td>f1_score</td><td>0.82243</td></tr><tr><td>fbeta_score</td><td>0.84181</td></tr><tr><td>ho_accuracy</td><td>0.882</td></tr><tr><td>ho_balanced_accuracy</td><td>0.89476</td></tr><tr><td>ho_f1_score</td><td>0.45872</td></tr><tr><td>ho_fbeta_score</td><td>0.35361</td></tr><tr><td>ho_precision</td><td>0.30675</td></tr><tr><td>ho_recall</td><td>0.90909</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BalRandForest_under_sampler</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/bahth1io' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/bahth1io</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022441-bahth1io/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022444-iggqdjgw</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/iggqdjgw' target="_blank">DesTree_over_sampler</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/iggqdjgw' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/iggqdjgw</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.69203</td></tr><tr><td>balanced_accuracy</td><td>0.69203</td></tr><tr><td>f1_score</td><td>0.64813</td></tr><tr><td>fbeta_score</td><td>0.70925</td></tr><tr><td>ho_accuracy</td><td>0.787</td></tr><tr><td>ho_balanced_accuracy</td><td>0.68182</td></tr><tr><td>ho_f1_score</td><td>0.22545</td></tr><tr><td>ho_fbeta_score</td><td>0.16578</td></tr><tr><td>ho_precision</td><td>0.14091</td></tr><tr><td>ho_recall</td><td>0.56364</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
# ...
# Find logs at: <code>./wandb/run-20251012_022535-1bdpu84e/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022537-qauylpkv</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/qauylpkv' target="_blank">RandForest_smote</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/qauylpkv' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/qauylpkv</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.78786</td></tr><tr><td>balanced_accuracy</td><td>0.78786</td></tr><tr><td>f1_score</td><td>0.78722</td></tr><tr><td>fbeta_score</td><td>0.78871</td></tr><tr><td>ho_accuracy</td><td>0.753</td></tr><tr><td>ho_balanced_accuracy</td><td>0.74089</td></tr><tr><td>ho_f1_score</td><td>0.24465</td></tr><tr><td>ho_fbeta_score</td><td>0.17498</td></tr><tr><td>ho_precision</td><td>0.14706</td></tr><tr><td>ho_recall</td><td>0.72727</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RandForest_smote</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/qauylpkv' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/qauylpkv</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022537-qauylpkv/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022544-ygjhp3o6</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/ygjhp3o6' target="_blank">BRandForest_smote</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/ygjhp3o6' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/ygjhp3o6</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.79263</td></tr><tr><td>balanced_accuracy</td><td>0.79263</td></tr><tr><td>f1_score</td><td>0.79512</td></tr><tr><td>fbeta_score</td><td>0.78931</td></tr><tr><td>ho_accuracy</td><td>0.744</td></tr><tr><td>ho_balanced_accuracy</td><td>0.74468</td></tr><tr><td>ho_f1_score</td><td>0.2426</td></tr><tr><td>ho_fbeta_score</td><td>0.1727</td></tr><tr><td>ho_precision</td><td>0.14488</td></tr><tr><td>ho_recall</td><td>0.74545</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BRandForest_smote</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/ygjhp3o6' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/ygjhp3o6</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022544-ygjhp3o6/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022552-pw4jm8u7</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/pw4jm8u7' target="_blank">SVC_smote</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/pw4jm8u7' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/pw4jm8u7</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.97425</td></tr><tr><td>balanced_accuracy</td><td>0.97425</td></tr><tr><td>f1_score</td><td>0.97391</td></tr><tr><td>fbeta_score</td><td>0.98178</td></tr><tr><td>ho_accuracy</td><td>0.968</td></tr><tr><td>ho_balanced_accuracy</td><td>0.90601</td></tr><tr><td>ho_f1_score</td><td>0.74194</td></tr><tr><td>ho_fbeta_score</td><td>0.69486</td></tr><tr><td>ho_precision</td><td>0.66667</td></tr><tr><td>ho_recall</td><td>0.83636</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SVC_smote</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/pw4jm8u7' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/pw4jm8u7</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022552-pw4jm8u7/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022559-y6v6g73p</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/y6v6g73p' target="_blank">BSVC_smote</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/y6v6g73p' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/y6v6g73p</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.9716</td></tr><tr><td>balanced_accuracy</td><td>0.9716</td></tr><tr><td>f1_score</td><td>0.97116</td></tr><tr><td>fbeta_score</td><td>0.98026</td></tr><tr><td>ho_accuracy</td><td>0.972</td></tr><tr><td>ho_balanced_accuracy</td><td>0.91669</td></tr><tr><td>ho_f1_score</td><td>0.77049</td></tr><tr><td>ho_fbeta_score</td><td>0.72755</td></tr><tr><td>ho_precision</td><td>0.70149</td></tr><tr><td>ho_recall</td><td>0.85455</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BSVC_smote</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/y6v6g73p' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/y6v6g73p</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022559-y6v6g73p/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/home/user/engineering_for_ai/course_work/wandb/run-20251012_022607-fc272xxf</code>
# Syncing run <strong><a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/fc272xxf' target="_blank">BalRandForest_smote</a></strong> to <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a>
#  View run at <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/fc272xxf' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/fc272xxf</a>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>balanced_accuracy</td><td>▁</td></tr><tr><td>f1_score</td><td>▁</td></tr><tr><td>fbeta_score</td><td>▁</td></tr><tr><td>ho_accuracy</td><td>▁</td></tr><tr><td>ho_balanced_accuracy</td><td>▁</td></tr><tr><td>ho_f1_score</td><td>▁</td></tr><tr><td>ho_fbeta_score</td><td>▁</td></tr><tr><td>ho_precision</td><td>▁</td></tr><tr><td>ho_recall</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.98718</td></tr><tr><td>balanced_accuracy</td><td>0.98718</td></tr><tr><td>f1_score</td><td>0.98715</td></tr><tr><td>fbeta_score</td><td>0.98876</td></tr><tr><td>ho_accuracy</td><td>0.974</td></tr><tr><td>ho_balanced_accuracy</td><td>0.83213</td></tr><tr><td>ho_f1_score</td><td>0.74</td></tr><tr><td>ho_fbeta_score</td><td>0.78723</td></tr><tr><td>ho_precision</td><td>0.82222</td></tr><tr><td>ho_recall</td><td>0.67273</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BalRandForest_smote</strong> at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/fc272xxf' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison/runs/fc272xxf</a><br> View project at: <a href='https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison' target="_blank">https://wandb.ai/the_ranch/imbalanced_dataset_model_comparison</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251012_022607-fc272xxf/logs</code>
